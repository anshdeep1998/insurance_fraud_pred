# %%
import pandas as pd

# %%
df = pd.read_csv("imputed_data.csv")
df
# Out:
#       Unnamed: 0  months_as_customer policy_csl  policy_deductable  \
# 0              0                 328    250/500               1000
# 1              1                 228    250/500               2000
# 2              2                 134    100/300               2000
# 3              3                 256    250/500               2000
# 4              4                 228   500/1000               1000
# ...          ...                 ...        ...                ...
# 1145        1145                 265    250/500               1000
# 1146        1146                 163    100/300                500
# 1147        1147                 355   500/1000               2000
# 1148        1148                 175   500/1000               1000
# 1149        1149                 192    100/300               1000
#
#       policy_annual_premium  umbrella_limit insured_sex  \
# 0                   1406.91               0        MALE
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                       0
# months_as_customer               0
# policy_csl                       0
# policy_deductable                0
# policy_annual_premium            0
# umbrella_limit                   0
# insured_sex                      0
# insured_education_level          0
# insured_occupation               0
# insured_relationship             0
# capital-gains                    0
# capital-loss                     0
# incident_type                    0
# collision_type                   0
# incident_severity                0
# authorities_contacted            0
# incident_hour_of_the_day         0
# number_of_vehicles_involved      0
# property_damage                  0
# bodily_injuries                  0
# witnesses                        0
# police_report_available        450
# injury_claim                     0
# property_claim                   0
# vehicle_claim                    0
# fraud_reported                   0
# dtype: int64

# %%
df['police_report_available'].isnull().sum()
# Out:
# 450

# %%
df['property_damage'].value_counts()
# Out:
# NO     828
# YES    322
# Name: property_damage, dtype: int64
